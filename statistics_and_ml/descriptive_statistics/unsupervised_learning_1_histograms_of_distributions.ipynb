# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1. Create dataset
# 2. Plot with line graph
# 3. Plot with histogram
# 4. Explain

# %%
num_data_points = 1001
dataset = np.linspace(-4, 4, num_data_points)
print(dataset)
# Out:
# [-4.    -3.992 -3.984 ...  3.984  3.992  4.   ]

# %%
# Plotting on a line plot
plt.hist(dataset, bins=40)
# Out:
# (array([25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 25., 26., 24.,
#         25., 25., 25., 26., 24., 25., 25., 25., 25., 25., 26., 24., 25.,
#         25., 25., 26., 24., 25., 25., 25., 26., 24., 25., 25., 25., 26.,
#         25.]),
#  array([-4. , -3.8, -3.6, -3.4, -3.2, -3. , -2.8, -2.6, -2.4, -2.2, -2. ,
#         -1.8, -1.6, -1.4, -1.2, -1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,
#          0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,  2.2,  2.4,
#          2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ]),
#  <BarContainer object of 40 artists>)
